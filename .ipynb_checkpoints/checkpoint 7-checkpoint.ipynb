# %%
from sklearn.ensemble import RandomForestClassifier 
from sklearn import metrics  
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn import tree   
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
import pandas as pd
df=pd.read_csv("new_clean_titanic.csv")
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  PassengerId  Survived  Pclass  Sex   Age  SibSp  \
# 0           0             0          343         0       2    1  28.0      0
# 1           1             1           76         0       3    1  25.0      0
# 2           2             2          641         0       3    1  20.0      0
# 3           3             3          568         0       3    0  29.0      0
# 4           4             4          672         0       1    1  31.0      1
#
#    Parch      Ticket     Fare Embarked  Title  FamilySize
# 0      0      248740  13.0000        S      1           0
# 1      0      348123   7.6500        S      1           0
# 2      0      350050   7.8542        S      1           0
# 3      4      349909  21.0750        S      1           4
# 4      0  F.C. 12750  52.0000        S      1           1

# %%
df=df.drop(["Unnamed: 0"],axis=1)
df=df.drop(["Unnamed: 0.1"],axis=1)
df.head()
# Out:
#    PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch      Ticket  \
# 0          343         0       2    1  28.0      0      0      248740
# 1           76         0       3    1  25.0      0      0      348123
# 2          641         0       3    1  20.0      0      0      350050
# 3          568         0       3    0  29.0      0      4      349909
# 4          672         0       1    1  31.0      1      0  F.C. 12750
#
#       Fare Embarked  Title  FamilySize
# 0  13.0000        S      1           0
# 1   7.6500        S      1           0
# 2   7.8542        S      1           0
# 3  21.0750        S      1           4
# 4  52.0000        S      1           1

# %%
x=df[["Pclass","Sex","Age","Fare","Title","FamilySize"]]
y= df["Survived"]

#splitting data
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.20,random_state=10)

#applying tree algorithm
tree1 = tree.DecisionTreeClassifier()  
tree1.fit(x_train, y_train)   #fitting our model
y_pred=tree1.predict(x_test)   # evaluating our model
print("score:{}".format(accuracy_score(y_test, y_pred)))
# Out:
# score:0.7932960893854749

# %%
import graphviz
dot_data= tree.export_graphviz(tree1,out_file=None)
graph=graphviz.Source(dot_data)
graph.render("data")
graph

# %% [raw]
# la caractristique la plus impotante est le sex la caracteristique la moins importante est le tarif

# %%
tree1=tree.DecisionTreeClassifier(splitter=4,criterion=0.3)

# %%
tree1 = tree.DecisionTreeClassifier()  
tree1.fit(x_train, y_train)   #fitting our model
y_pred=tree1.predict(x_test)   # evaluating our model
print("score:{}".format(accuracy_score(y_test, y_pred)))
# Out:
# score:0.7932960893854749

# %% [raw]
# 0.8>0.7 l accuracy est meilleur

# %%
clf=RandomForestClassifier(n_estimators=10)  #Creating a random forest with 100 decision trees
clf.fit(x_train, y_train)  #Training our model
y_pred=clf.predict(x_test)  #testing our model
print("Accuracy:", metrics.accuracy_score(y_test, y_pred))  #Measuring the accuracy of our model
# Out:
# Accuracy: 0.8212290502793296

# %%
clf=RandomForestClassifier(n_estimators=100)  #Creating a random forest with 100 decision trees
clf.fit(x_train, y_train)  #Training our model
y_pred=clf.predict(x_test)  #testing our model
print("Accuracy:", metrics.accuracy_score(y_test, y_pred))  #Measuring the accuracy of our model
# Out:
# Accuracy: 0.8324022346368715

# %%
clf=RandomForestClassifier(n_estimators=50)  #Creating a random forest with 100 decision trees
clf.fit(x_train, y_train)  #Training our model
y_pred=clf.predict(x_test)  #testing our model
print("Accuracy:", metrics.accuracy_score(y_test, y_pred))  #Measuring the accuracy of our model
# Out:
# Accuracy: 0.8324022346368715

# %% [raw]
# plus le nombre d estimateur est eleve plus l accuracy est meilleur mais quand elle atteint un nombre precis de "tree" le "n_estimators"ne change rien
